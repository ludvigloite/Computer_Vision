# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2b)
# ![task2b_binary_train_loss.png](attachment:task2b_binary_train_loss.png)

# %% [markdown]
# ## Task 2c)
# ![task2b_binary_train_accuracy.png](attachment:task2b_binary_train_accuracy.png)

# %% [markdown]
# ## Task 2d)
# Early stopping kicks in at epoch #33, in which case the validation loss was has not improved over 10 steps, and converges around 0.067

# %% [markdown]
# ## Task 2e)
# ![task2e_train_accuracy_shuffle_difference.png](attachment:task2e_train_accuracy_shuffle_difference.png)
#
# As is apparent in both the validation loss and the train accuracy, our model suffers greatly from performance spikes once every sixth epoch.
#
# We believe these spikes are caused by bad images in one of the 32 batches of our training data set, which makes sense considering the spike in training loss once every epoch. Since validation is performed on an entirely different data set only once every fifth training step, this problem does not become apparent until we run a validation step right after training our model on this bad batch. With 32 batches in our training data, and running validation once every fifth step, this accounts for the performance spike in validation loss and accuracy once every 192th step.
#
# By introducing data set shuffling, we can avoid this problem to some extent. We will of course still suffer from the same bad data, but spread over different batches every epoch such that the model is not consistently updated with bad weights at regular intervals. Additionally, since shuffling the data set allows for more consistent validation loss results, we can confidently stop training out model much earlier to avoid overfitting. (Siste setning ok?)

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Task 3b)
# ![task3b_softmax_train_loss.png](attachment:task3b_softmax_train_loss.png)

# %% [markdown]
# ## Task 3c)
# ![task3b_softmax_train_accuracy.png](attachment:task3b_softmax_train_accuracy.png)

# %% [markdown]
# ## Task 3d)
# As can be seen in the above two figures, there are some signs of overfitting in our model. It is most apparent on the validation accuracy vs. training accuracy, where the training accuracy diverges from the validation accuracy around 2000 training steps. However, since the validation accuracy keeps improving even past this point, there is no reason to stop training early.

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# Fill in image of hand-written notes which are easy to read, or latex equations here

# %% [markdown]
# ## Task 4b)
# ![](task4b_softmax_weight.png)
#
# Lambda is proportional to the degree of complexity penalization of our model. A complex model can be recognized by having many large weights and variances. Hence, when visualized, less complex weights from higher values of lambda consititute smoother and less noisy images. This is shown in the figure above.

# %% [markdown]
# ## Task 4c)
# ![](task4c_l2_reg_accuracy.png)

# %% [markdown]
# ## Task 4d)
# When applying regularization to our model, we essentially constrict the gradients of every training step from updating the weights to the optimal value in regard to the cross entropy loss. Thus, the performance is degraded. However, since regularization improves generalization, our regularized model would likely have an improved validation accuracy on an entirely new data set.

# %% [markdown]
# ## Task 4e)
# ![](task4d_l2_reg_norms.png)
#
# As is apparent in the figure above, higher values of lambda affect the length of our model weight vector. Again, as explained in 4b), this is likely because high values of lambda penalize complex models with large weights. The model is made significantly simpler and more generalized when the L2-norm of the weight vector is small.
